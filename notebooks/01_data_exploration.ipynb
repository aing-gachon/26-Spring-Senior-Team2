# %% [markdown]
# # CXR8 Data Exploration & MONAI Transform Test
#
# 이 노트북은 전처리된 데이터셋의 이미지 로드 확인과 `src/transforms.py`의 파이프라인 검증을 목적으로 합니다.

# %%
import os
import matplotlib.pyplot as plt
from src.dataset import CXR8Dataset
from src.transforms import get_base_transforms

# 데이터셋 초기화
raw_img_dir = "../data/raw"
csv_path = "../data/Data_Entry_2017.csv"

transforms = get_base_transforms()
dataset = CXR8Dataset(
    raw_img_dir=raw_img_dir,
    csv_path=csv_path,
    transform=transforms
)

print(f"Total Data Samples: {len(dataset)}")
